# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('max.columns',None)
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_excel('Datasets/Modified_carvago_data.xlsx')
data.rename(columns={"Car Name": "Car_Name", "Kms driven": "Kms_driven",'First registration':'First_registration','Fuel type':'Fuel_type','Drive type':'Drive_type'},inplace=True)

# %% [markdown]
# ### Initial Data Analysis

# %%
data.shape
# Out:
# (10020, 17)

# %%
data.dtypes
# Out:
# Index                    int64
# Car_Name                object
# Kms_driven              object
# First_registration      object
# Power                   object
# Transmission            object
# Fuel_type               object
# Vendor                  object
# Ratings                float64
# Location                object
# Price in Euro           object
# Price without Vat       object
# With or without Tax     object
# Drive_type              object
# Features_1              object
# Features_2              object
# Features_3              object
# dtype: object

# %%
data.isna().sum()
# Out:
# Index                     0
# Car_Name                  0
# Kms_driven                0
# First_registration        0
# Power                     0
# Transmission              0
# Fuel_type               422
# Vendor                    0
# Ratings                3562
# Location                  0
# Price in Euro             1
# Price without Vat         1
# With or without Tax    4376
# Drive_type             7430
# Features_1              810
# Features_2              951
# Features_3             4564
# dtype: int64

# %%
data[data['Kms_driven'].str.endswith(' km')].shape,data[data['Kms_driven'].str.endswith(' km')==False].shape
# Out:
# ((9975, 17), (45, 17))

# %%
data[data['Kms_driven'].str.endswith(' km')==False]
# Out:
#       Index                                Car_Name Kms_driven  \
# 535     535             Volkswagen T-Roc TSI 110 kW     1/2022
# 570     570                      Hyundai i30 118 kW     1/2022
# 591     591                Audi Q2 35 TFSI S 110 kW     1/2022
# 626     626  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 633     633  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 777     777                Audi Q2 35 TFSI S 110 kW     1/2022
# 816     816                          Audi A4 150 kW     1/2022
# 860     860                      Hyundai i30 118 kW     1/2022
# 1171   1171  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 1177   1177                           BMW X1 110 kW     2/2022
# 1233   1233  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 1332   1332                    Volkswagen up! 85 kW     1/2022
# 2112   2112                Audi Q3 35 TFSI S 110 kW     1/2022
# 2327   2327                    Volkswagen up! 48 kW     1/2022
# 2698   2698                   Nissan Qashqai 103 kW     1/2021
# 3031   3031    MINI Cooper D Countryman All4 110 kW     2/2022
# 3521   3521                      Dacia Spring 33 kW     1/2021
# 3735   3735  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 3778   3778    Volkswagen T-Cross 1.0 TSI OPF 81 kW     1/2022
# 3797   3797                        Honda Jazz 72 kW     6/2021
# 3806   3806    MINI Cooper D Countryman All4 110 kW     2/2022
# 3810   3810                Audi Q3 35 TFSI S 110 kW     1/2021
# 4671   4671                      Dacia Spring 33 kW     1/2021
# 5276   5276         Volkswagen T-Roc 1.5 TSI 110 kW     1/2022
# 5282   5282                Audi Q3 35 TFSI S 110 kW     1/2021
# 5337   5337                Audi Q2 35 TFSI S 110 kW     1/2022
# 5507   5507                  Volkswagen Caddy 90 kW     1/2022
# 5619   5619                           BMW X1 100 kW     2/2022
# 5885   5885                      Dacia Spring 33 kW     1/2021
# 5942   5942             Volkswagen T-Roc TSI 110 kW     1/2022
# 6097   6097                          Kia EV6 239 kW     1/2022
# 6537   6537                 BMW X1 Automatic 140 kW     2/2022
# 6543   6543  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2021
# 6666   6666                Audi Q2 35 TFSI S 110 kW     1/2022
# 6977   6977                      Dacia Spring 33 kW     1/2021
# 7220   7220            Mercedes-Benz GLA 200 120 kW     1/2022
# 7462   7462           Volkswagen ID.4 77 kWh 150 kW     1/2022
# 7914   7914                 BMW X1 Automatic 140 kW     2/2022
# 8078   8078                           BMW X3 135 kW     2/2022
# 8448   8448                Audi Q3 35 TFSI S 110 kW     1/2022
# 8492   8492                           BMW X4 135 kW     2/2022
# 9141   9141                Audi Q2 35 TFSI S 110 kW     1/2022
# 9452   9452     Seat Tarraco 1.5 TSI ACT OPF 110 kW     1/2021
# 9652   9652                           BMW X3 135 kW     2/2022
# 9793   9793                      MINI Cooper 100 kW     2/2022
#
#      First_registration      Power Transmission Fuel_type      Vendor  \
# 535              110 kW  Automatic       Petrol       NaN  Dealership
# 570              118 kW     Manual       Petrol       NaN  Dealership
# 591              110 kW  Automatic       Petrol       NaN  Dealership
# 626              150 kW  Automatic       Diesel       4x4  Dealership
# 633              150 kW  Automatic       Diesel       4x4  Dealership
# 777              110 kW  Automatic       Petrol       NaN  Dealership
# 816              150 kW  Automatic       Petrol       4x4  Dealership
# 860              118 kW     Manual       Petrol       NaN  Dealership
# 1171             150 kW  Automatic       Diesel       4x4  Dealership
# 1177             110 kW  Automatic       Diesel       NaN  Dealership
# 1233             150 kW  Automatic       Diesel       4x4  Dealership
# 1332              85 kW     Manual       Petrol       NaN  Dealership
# 2112             110 kW  Automatic       Petrol       NaN  Dealership
# 2327              48 kW     Manual       Petrol       NaN  Dealership
# 2698             103 kW     Manual       Hybrid       NaN  Dealership
# 3031             110 kW  Automatic       Diesel       4x4  Dealership
# 3521              33 kW  Automatic     Electric       NaN  Dealership
# 3735             150 kW  Automatic       Diesel       4x4  Dealership
# 3778              81 kW     Manual       Petrol       NaN  Dealership
# 3797              72 kW  Automatic       Hybrid       NaN  Dealership
# 3806             110 kW  Automatic       Diesel       4x4  Dealership
# 3810             110 kW  Automatic       Petrol       NaN  Dealership
# 4671              33 kW  Automatic     Electric       NaN  Dealership
# 5276             110 kW     Manual       Petrol       NaN  Dealership
# 5282             110 kW  Automatic       Petrol       NaN  Dealership
# 5337             110 kW  Automatic       Petrol       NaN  Dealership
# 5507              90 kW     Manual       Diesel       NaN  Dealership
# 5619             100 kW  Automatic       Petrol       NaN  Dealership
# 5885              33 kW  Automatic     Electric       NaN  Dealership
# 5942             110 kW     Manual       Petrol       NaN  Dealership
# 6097             239 kW  Automatic     Electric       NaN  Dealership
# 6537             140 kW  Automatic       Diesel       NaN  Dealership
# 6543             150 kW  Automatic       Diesel       4x4  Dealership
# 6666             110 kW  Automatic       Petrol       NaN  Dealership
# 6977              33 kW  Automatic     Electric       NaN  Dealership
# 7220             120 kW  Automatic       Petrol       NaN  Dealership
# 7462             150 kW  Automatic     Electric       NaN  Dealership
# 7914             140 kW  Automatic       Diesel       NaN  Dealership
# 8078             135 kW  Automatic       Hybrid       4x4  Dealership
# 8448             110 kW  Automatic       Petrol       NaN  Dealership
# 8492             135 kW  Automatic       Hybrid       4x4  Dealership
# 9141             110 kW  Automatic       Petrol       NaN  Dealership
# 9452             110 kW     Manual       Petrol       NaN  Dealership
# 9652             135 kW  Automatic       Hybrid       4x4  Dealership
# 9793             100 kW  Automatic       Petrol       NaN  Dealership
#
#       Ratings     Location Price in Euro Price without Vat  \
# 535       NaN       Poland      23 249 €          19 214 €
# 570       NaN       Poland      21 399 €          17 685 €
# 591       NaN       Poland      31 099 €          25 702 €
# 626       NaN       Poland      49 349 €          40 784 €
# 633       NaN       Poland      53 649 €          44 338 €
# 777       NaN       Poland      31 749 €          26 239 €
# 816       NaN       Poland      47 049 €          38 883 €
# 860       NaN       Poland      22 099 €          18 264 €
# 1171      NaN       Poland      55 699 €          46 032 €
# 1177      4.5        Italy      38 099 €    Not deductible
# 1233      NaN       Poland      55 899 €          46 198 €
# 1332      NaN       Poland      14 599 €          12 065 €
# 2112      NaN       Poland      38 449 €          31 776 €
# 2327      NaN       Poland      13 749 €          11 363 €
# 2698      NaN       Poland      21 399 €          17 685 €
# 3031      4.5        Italy      34 799 €    Not deductible
# 3521      NaN  Netherlands      19 499 €          16 115 €
# 3735      NaN       Poland      49 349 €          40 784 €
# 3778      NaN       Poland      19 649 €          16 239 €
# 3797      5.0      Austria      21 549 €    Not deductible
# 3806      4.5        Italy      35 499 €    Not deductible
# 3810      NaN       Poland      39 849 €          32 933 €
# 4671      NaN  Netherlands      19 899 €          16 445 €
# 5276      NaN       Poland      24 649 €          20 371 €
# 5282      NaN       Poland      41 549 €          34 338 €
# 5337      NaN       Poland      32 199 €          26 611 €
# 5507      NaN  Netherlands      30 649 €          25 330 €
# 5619      4.5        Italy      31 349 €    Not deductible
# 5885      NaN  Netherlands      20 299 €          16 776 €
# 5942      NaN       Poland      21 549 €          17 809 €
# 6097      NaN  Netherlands      56 099 €          46 363 €
# 6537      4.5        Italy      36 399 €    Not deductible
# 6543      NaN       Poland      52 999 €          43 801 €
# 6666      NaN       Poland      33 299 €          27 520 €
# 6977      NaN  Netherlands      20 549 €          16 983 €
# 7220      NaN       Poland      42 299 €          34 958 €
# 7462      NaN  Netherlands      52 599 €          43 470 €
# 7914      4.5        Italy      40 699 €    Not deductible
# 8078      4.5        Italy      60 849 €    Not deductible
# 8448      NaN       Poland      44 649 €          36 900 €
# 8492      4.5        Italy      55 499 €    Not deductible
# 9141      NaN       Poland      34 799 €          28 760 €
# 9452      NaN       Poland      30 849 €          25 495 €
# 9652      4.5        Italy      52 099 €    Not deductible
# 9793      4.5        Italy      25 649 €    Not deductible
#
#      With or without Tax Drive_type                           Features_1  \
# 535      without 21% VAT        NaN  Parking assist system self-steering
# 570      without 21% VAT        NaN                   Heated front seats
# 591      without 21% VAT        NaN                      Digital cockpit
# 626      without 21% VAT        NaN              Adaptive cruise control
# 633      without 21% VAT        NaN                        Automatic A/C
# 777      without 21% VAT        NaN                      Digital cockpit
# 816      without 21% VAT        NaN                       LED headlights
# 860      without 21% VAT        NaN                   Heated front seats
# 1171     without 21% VAT        NaN                       LED headlights
# 1177                 NaN        NaN                                  NaN
# 1233     without 21% VAT        NaN                       LED headlights
# 1332     without 21% VAT        NaN                    Adaptive lighting
# 2112     without 21% VAT        NaN                                  NaN
# 2327     without 21% VAT        NaN                                  NaN
# 2698     without 21% VAT        NaN                       LED headlights
# 3031                 NaN        NaN                                  NaN
# 3521     without 21% VAT        NaN                            Bluetooth
# 3735     without 21% VAT        NaN                       LED headlights
# 3778     without 21% VAT        NaN                         Android auto
# 3797                 NaN        NaN                       LED headlights
# 3806                 NaN        NaN                                  NaN
# 3810     without 21% VAT        NaN                                Alarm
# 4671     without 21% VAT        NaN                        Apple CarPlay
# 5276     without 21% VAT        NaN                      Digital cockpit
# 5282     without 21% VAT        NaN                                Alarm
# 5337     without 21% VAT        NaN                      Digital cockpit
# 5507     without 21% VAT        NaN                       LED headlights
# 5619                 NaN        NaN                                  NaN
# 5885     without 21% VAT        NaN                            Bluetooth
# 5942     without 21% VAT        NaN  Parking assist system self-steering
# 6097     without 21% VAT        NaN                                  NaN
# 6537                 NaN        NaN                                  NaN
# 6543     without 21% VAT        NaN                    Navigation system
# 6666     without 21% VAT        NaN                      Digital cockpit
# 6977     without 21% VAT        NaN                        Apple CarPlay
# 7220     without 21% VAT        NaN  Parking assist system self-steering
# 7462     without 21% VAT        NaN                       LED headlights
# 7914                 NaN        NaN                                  NaN
# 8078                 NaN        NaN                                  NaN
# 8448     without 21% VAT        NaN                                  NaN
# 8492                 NaN        NaN                                  NaN
# 9141     without 21% VAT        NaN                      Digital cockpit
# 9452     without 21% VAT        NaN  Parking assist system self-steering
# 9652                 NaN        NaN                                  NaN
# 9793                 NaN        NaN                                  NaN
#
#                    Features_2               Features_3
# 535           Digital cockpit                      NaN
# 570              Android auto                Bluetooth
# 591             Automatic A/C                      NaN
# 626      Bang & Olufsen audio                Bluetooth
# 633                     Alarm                      USB
# 777             Automatic A/C                      NaN
# 816           Digital cockpit        Navigation system
# 860              Android auto                Bluetooth
# 1171  Adaptive cruise control     Bang & Olufsen audio
# 1177                      NaN                      NaN
# 1233  Adaptive cruise control     Bang & Olufsen audio
# 1332              Rain sensor                      NaN
# 2112                      NaN                      NaN
# 2327                      NaN                      NaN
# 2698  Adaptive cruise control                      NaN
# 3031                      NaN                      NaN
# 3521             Light sensor        Hill-start assist
# 3735  Adaptive cruise control     Bang & Olufsen audio
# 3778                      NaN                      NaN
# 3797            Keyless entry  Adaptive cruise control
# 3806                      NaN                      NaN
# 3810                      NaN                      NaN
# 4671             Android auto        Navigation system
# 5276            Automatic A/C                    Alarm
# 5282                      NaN                      NaN
# 5337       Heated front seats            Automatic A/C
# 5507          Digital cockpit            Keyless entry
# 5619                      NaN                      NaN
# 5885             Light sensor        Hill-start assist
# 5942           LED headlights                      NaN
# 6097                      NaN                      NaN
# 6537                      NaN                      NaN
# 6543        On-board computer                    Alarm
# 6666            Automatic A/C                    Alarm
# 6977             Android auto        Navigation system
# 7220           LED headlights                      NaN
# 7462  Adaptive cruise control       Heated front seats
# 7914                      NaN                      NaN
# 8078                      NaN                      NaN
# 8448                      NaN                      NaN
# 8492                      NaN                      NaN
# 9141            Automatic A/C                    Alarm
# 9452           LED headlights                      NaN
# 9652                      NaN                      NaN
# 9793                      NaN                      NaN

# %% [markdown]
# ### Handling misplaced values

# %%
            
def get_feature_name(value):
    if value != np.nan:
        if '/' in value:
            if value.split('/')[0].isnumeric() and value.split('/')[1].isnumeric():
                return 'First_registration'
        elif 'kW' in value:
            return 'Power'
        elif value in ['Automatic', 'Manual']:
            return 'Transmission'
        elif value in ['Diesel','Petrol','Electric','CNG','Hydrogen','LPG','Other fuel type','Hybrid']:
            return 'Fuel_type'
        elif value in ['2x4','4x4']:
            return 'Drive_type'
        elif 'km' in value:
            return 'Kms_driven'
            
    else :
        return 'none'

# %%
columns = ['Kms_driven','First_registration','Power','Transmission','Fuel_type','Drive_type']

# %%
value = '' 
name = ''


def update_value(val,f_name,idx):
    #print(data.loc[idx,f_name])
    if str(data.loc[idx,f_name]) != 'nan':
        global value
        value = data.loc[idx,f_name]
    else:
        value = ''
    data.loc[idx,f_name] = val
    return


for i in data.values:
    skip = 0
    for c in range(0,len(columns)):
        if c == 0 or skip==1:
            if str(data.loc[i[0],columns[c]])!='nan':
                value = str(data.loc[i[0],columns[c]])
                skip = 0
            elif str(data.loc[i[0],columns[c]])=='nan':
                if name==columns[c]:
                    data.loc[i[0],columns[c]] = value
                else:
                    continue
                
        if len(value)==0:
            continue
        name = get_feature_name(value)
        if name == columns[c]:
            skip = 1
            continue
        v = value
        n = name
        #print(v,n,i[0])
        update_value(v,n,i[0])

# %%
data[data['Kms_driven'].str.endswith(' km')==False]
# Out:
#       Index                                Car_Name Kms_driven  \
# 535     535             Volkswagen T-Roc TSI 110 kW     1/2022
# 570     570                      Hyundai i30 118 kW     1/2022
# 591     591                Audi Q2 35 TFSI S 110 kW     1/2022
# 626     626  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 633     633  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 777     777                Audi Q2 35 TFSI S 110 kW     1/2022
# 816     816                          Audi A4 150 kW     1/2022
# 860     860                      Hyundai i30 118 kW     1/2022
# 1171   1171  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 1177   1177                           BMW X1 110 kW     2/2022
# 1233   1233  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 1332   1332                    Volkswagen up! 85 kW     1/2022
# 2112   2112                Audi Q3 35 TFSI S 110 kW     1/2022
# 2327   2327                    Volkswagen up! 48 kW     1/2022
# 2698   2698                   Nissan Qashqai 103 kW     1/2021
# 3031   3031    MINI Cooper D Countryman All4 110 kW     2/2022
# 3521   3521                      Dacia Spring 33 kW     1/2021
# 3735   3735  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 3778   3778    Volkswagen T-Cross 1.0 TSI OPF 81 kW     1/2022
# 3797   3797                        Honda Jazz 72 kW     6/2021
# 3806   3806    MINI Cooper D Countryman All4 110 kW     2/2022
# 3810   3810                Audi Q3 35 TFSI S 110 kW     1/2021
# 4671   4671                      Dacia Spring 33 kW     1/2021
# 5276   5276         Volkswagen T-Roc 1.5 TSI 110 kW     1/2022
# 5282   5282                Audi Q3 35 TFSI S 110 kW     1/2021
# 5337   5337                Audi Q2 35 TFSI S 110 kW     1/2022
# 5507   5507                  Volkswagen Caddy 90 kW     1/2022
# 5619   5619                           BMW X1 100 kW     2/2022
# 5885   5885                      Dacia Spring 33 kW     1/2021
# 5942   5942             Volkswagen T-Roc TSI 110 kW     1/2022
# 6097   6097                          Kia EV6 239 kW     1/2022
# 6537   6537                 BMW X1 Automatic 140 kW     2/2022
# 6543   6543  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2021
# 6666   6666                Audi Q2 35 TFSI S 110 kW     1/2022
# 6977   6977                      Dacia Spring 33 kW     1/2021
# 7220   7220            Mercedes-Benz GLA 200 120 kW     1/2022
# 7462   7462           Volkswagen ID.4 77 kWh 150 kW     1/2022
# 7914   7914                 BMW X1 Automatic 140 kW     2/2022
# 8078   8078                           BMW X3 135 kW     2/2022
# 8448   8448                Audi Q3 35 TFSI S 110 kW     1/2022
# 8492   8492                           BMW X4 135 kW     2/2022
# 9141   9141                Audi Q2 35 TFSI S 110 kW     1/2022
# 9452   9452     Seat Tarraco 1.5 TSI ACT OPF 110 kW     1/2021
# 9652   9652                           BMW X3 135 kW     2/2022
# 9793   9793                      MINI Cooper 100 kW     2/2022
#
#      First_registration   Power Transmission Fuel_type      Vendor  Ratings  \
# 535              1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 570              1/2022  118 kW       Manual    Petrol  Dealership      NaN
# 591              1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 626              1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 633              1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 777              1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 816              1/2022  150 kW    Automatic    Petrol  Dealership      NaN
# 860              1/2022  118 kW       Manual    Petrol  Dealership      NaN
# 1171             1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 1177             2/2022  110 kW    Automatic    Diesel  Dealership      4.5
# 1233             1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 1332             1/2022   85 kW       Manual    Petrol  Dealership      NaN
# 2112             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 2327             1/2022   48 kW       Manual    Petrol  Dealership      NaN
# 2698             1/2021  103 kW       Manual    Hybrid  Dealership      NaN
# 3031             2/2022  110 kW    Automatic    Diesel  Dealership      4.5
# 3521             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 3735             1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 3778             1/2022   81 kW       Manual    Petrol  Dealership      NaN
# 3797             6/2021   72 kW    Automatic    Hybrid  Dealership      5.0
# 3806             2/2022  110 kW    Automatic    Diesel  Dealership      4.5
# 3810             1/2021  110 kW    Automatic    Petrol  Dealership      NaN
# 4671             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 5276             1/2022  110 kW       Manual    Petrol  Dealership      NaN
# 5282             1/2021  110 kW    Automatic    Petrol  Dealership      NaN
# 5337             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 5507             1/2022   90 kW       Manual    Diesel  Dealership      NaN
# 5619             2/2022  100 kW    Automatic    Petrol  Dealership      4.5
# 5885             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 5942             1/2022  110 kW       Manual    Petrol  Dealership      NaN
# 6097             1/2022  239 kW    Automatic  Electric  Dealership      NaN
# 6537             2/2022  140 kW    Automatic    Diesel  Dealership      4.5
# 6543             1/2021  150 kW    Automatic    Diesel  Dealership      NaN
# 6666             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 6977             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 7220             1/2022  120 kW    Automatic    Petrol  Dealership      NaN
# 7462             1/2022  150 kW    Automatic  Electric  Dealership      NaN
# 7914             2/2022  140 kW    Automatic    Diesel  Dealership      4.5
# 8078             2/2022  135 kW    Automatic    Hybrid  Dealership      4.5
# 8448             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 8492             2/2022  135 kW    Automatic    Hybrid  Dealership      4.5
# 9141             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 9452             1/2021  110 kW       Manual    Petrol  Dealership      NaN
# 9652             2/2022  135 kW    Automatic    Hybrid  Dealership      4.5
# 9793             2/2022  100 kW    Automatic    Petrol  Dealership      4.5
#
#          Location Price in Euro Price without Vat With or without Tax  \
# 535        Poland      23 249 €          19 214 €     without 21% VAT
# 570        Poland      21 399 €          17 685 €     without 21% VAT
# 591        Poland      31 099 €          25 702 €     without 21% VAT
# 626        Poland      49 349 €          40 784 €     without 21% VAT
# 633        Poland      53 649 €          44 338 €     without 21% VAT
# 777        Poland      31 749 €          26 239 €     without 21% VAT
# 816        Poland      47 049 €          38 883 €     without 21% VAT
# 860        Poland      22 099 €          18 264 €     without 21% VAT
# 1171       Poland      55 699 €          46 032 €     without 21% VAT
# 1177        Italy      38 099 €    Not deductible                 NaN
# 1233       Poland      55 899 €          46 198 €     without 21% VAT
# 1332       Poland      14 599 €          12 065 €     without 21% VAT
# 2112       Poland      38 449 €          31 776 €     without 21% VAT
# 2327       Poland      13 749 €          11 363 €     without 21% VAT
# 2698       Poland      21 399 €          17 685 €     without 21% VAT
# 3031        Italy      34 799 €    Not deductible                 NaN
# 3521  Netherlands      19 499 €          16 115 €     without 21% VAT
# 3735       Poland      49 349 €          40 784 €     without 21% VAT
# 3778       Poland      19 649 €          16 239 €     without 21% VAT
# 3797      Austria      21 549 €    Not deductible                 NaN
# 3806        Italy      35 499 €    Not deductible                 NaN
# 3810       Poland      39 849 €          32 933 €     without 21% VAT
# 4671  Netherlands      19 899 €          16 445 €     without 21% VAT
# 5276       Poland      24 649 €          20 371 €     without 21% VAT
# 5282       Poland      41 549 €          34 338 €     without 21% VAT
# 5337       Poland      32 199 €          26 611 €     without 21% VAT
# 5507  Netherlands      30 649 €          25 330 €     without 21% VAT
# 5619        Italy      31 349 €    Not deductible                 NaN
# 5885  Netherlands      20 299 €          16 776 €     without 21% VAT
# 5942       Poland      21 549 €          17 809 €     without 21% VAT
# 6097  Netherlands      56 099 €          46 363 €     without 21% VAT
# 6537        Italy      36 399 €    Not deductible                 NaN
# 6543       Poland      52 999 €          43 801 €     without 21% VAT
# 6666       Poland      33 299 €          27 520 €     without 21% VAT
# 6977  Netherlands      20 549 €          16 983 €     without 21% VAT
# 7220       Poland      42 299 €          34 958 €     without 21% VAT
# 7462  Netherlands      52 599 €          43 470 €     without 21% VAT
# 7914        Italy      40 699 €    Not deductible                 NaN
# 8078        Italy      60 849 €    Not deductible                 NaN
# 8448       Poland      44 649 €          36 900 €     without 21% VAT
# 8492        Italy      55 499 €    Not deductible                 NaN
# 9141       Poland      34 799 €          28 760 €     without 21% VAT
# 9452       Poland      30 849 €          25 495 €     without 21% VAT
# 9652        Italy      52 099 €    Not deductible                 NaN
# 9793        Italy      25 649 €    Not deductible                 NaN
#
#      Drive_type                           Features_1               Features_2  \
# 535         NaN  Parking assist system self-steering          Digital cockpit
# 570         NaN                   Heated front seats             Android auto
# 591         NaN                      Digital cockpit            Automatic A/C
# 626         4x4              Adaptive cruise control     Bang & Olufsen audio
# 633         4x4                        Automatic A/C                    Alarm
# 777         NaN                      Digital cockpit            Automatic A/C
# 816         4x4                       LED headlights          Digital cockpit
# 860         NaN                   Heated front seats             Android auto
# 1171        4x4                       LED headlights  Adaptive cruise control
# 1177        NaN                                  NaN                      NaN
# 1233        4x4                       LED headlights  Adaptive cruise control
# 1332        NaN                    Adaptive lighting              Rain sensor
# 2112        NaN                                  NaN                      NaN
# 2327        NaN                                  NaN                      NaN
# 2698        NaN                       LED headlights  Adaptive cruise control
# 3031        4x4                                  NaN                      NaN
# 3521        NaN                            Bluetooth             Light sensor
# 3735        4x4                       LED headlights  Adaptive cruise control
# 3778        NaN                         Android auto                      NaN
# 3797        NaN                       LED headlights            Keyless entry
# 3806        4x4                                  NaN                      NaN
# 3810        NaN                                Alarm                      NaN
# 4671        NaN                        Apple CarPlay             Android auto
# 5276        NaN                      Digital cockpit            Automatic A/C
# 5282        NaN                                Alarm                      NaN
# 5337        NaN                      Digital cockpit       Heated front seats
# 5507        NaN                       LED headlights          Digital cockpit
# 5619        NaN                                  NaN                      NaN
# 5885        NaN                            Bluetooth             Light sensor
# 5942        NaN  Parking assist system self-steering           LED headlights
# 6097        NaN                                  NaN                      NaN
# 6537        NaN                                  NaN                      NaN
# 6543        4x4                    Navigation system        On-board computer
# 6666        NaN                      Digital cockpit            Automatic A/C
# 6977        NaN                        Apple CarPlay             Android auto
# 7220        NaN  Parking assist system self-steering           LED headlights
# 7462        NaN                       LED headlights  Adaptive cruise control
# 7914        NaN                                  NaN                      NaN
# 8078        4x4                                  NaN                      NaN
# 8448        NaN                                  NaN                      NaN
# 8492        4x4                                  NaN                      NaN
# 9141        NaN                      Digital cockpit            Automatic A/C
# 9452        NaN  Parking assist system self-steering           LED headlights
# 9652        4x4                                  NaN                      NaN
# 9793        NaN                                  NaN                      NaN
#
#                    Features_3
# 535                       NaN
# 570                 Bluetooth
# 591                       NaN
# 626                 Bluetooth
# 633                       USB
# 777                       NaN
# 816         Navigation system
# 860                 Bluetooth
# 1171     Bang & Olufsen audio
# 1177                      NaN
# 1233     Bang & Olufsen audio
# 1332                      NaN
# 2112                      NaN
# 2327                      NaN
# 2698                      NaN
# 3031                      NaN
# 3521        Hill-start assist
# 3735     Bang & Olufsen audio
# 3778                      NaN
# 3797  Adaptive cruise control
# 3806                      NaN
# 3810                      NaN
# 4671        Navigation system
# 5276                    Alarm
# 5282                      NaN
# 5337            Automatic A/C
# 5507            Keyless entry
# 5619                      NaN
# 5885        Hill-start assist
# 5942                      NaN
# 6097                      NaN
# 6537                      NaN
# 6543                    Alarm
# 6666                    Alarm
# 6977        Navigation system
# 7220                      NaN
# 7462       Heated front seats
# 7914                      NaN
# 8078                      NaN
# 8448                      NaN
# 8492                      NaN
# 9141                    Alarm
# 9452                      NaN
# 9652                      NaN
# 9793                      NaN

# %% [markdown]
# ### Cleaning Kms_driven

# %%
data['Kms_driven'] = data['Kms_driven'].apply(lambda x:x.strip())
data['Kms_driven'] = data['Kms_driven'].apply(lambda x: x[:-3] if x[-2:]=='km' else x)
data['Kms_driven'] = data['Kms_driven'].apply(lambda x:x.replace('\xa0',''))
data['Kms_driven'] = data['Kms_driven'].apply(lambda x:x.strip())

# %%
data[data['Kms_driven'].str.contains(r'[@#&$%+-/*]')]
# Out:
#       Index                                Car_Name Kms_driven  \
# 535     535             Volkswagen T-Roc TSI 110 kW     1/2022
# 570     570                      Hyundai i30 118 kW     1/2022
# 591     591                Audi Q2 35 TFSI S 110 kW     1/2022
# 626     626  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 633     633  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 777     777                Audi Q2 35 TFSI S 110 kW     1/2022
# 816     816                          Audi A4 150 kW     1/2022
# 860     860                      Hyundai i30 118 kW     1/2022
# 1171   1171  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 1177   1177                           BMW X1 110 kW     2/2022
# 1233   1233  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 1332   1332                    Volkswagen up! 85 kW     1/2022
# 2112   2112                Audi Q3 35 TFSI S 110 kW     1/2022
# 2327   2327                    Volkswagen up! 48 kW     1/2022
# 2698   2698                   Nissan Qashqai 103 kW     1/2021
# 3031   3031    MINI Cooper D Countryman All4 110 kW     2/2022
# 3521   3521                      Dacia Spring 33 kW     1/2021
# 3735   3735  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2022
# 3778   3778    Volkswagen T-Cross 1.0 TSI OPF 81 kW     1/2022
# 3797   3797                        Honda Jazz 72 kW     6/2021
# 3806   3806    MINI Cooper D Countryman All4 110 kW     2/2022
# 3810   3810                Audi Q3 35 TFSI S 110 kW     1/2021
# 4671   4671                      Dacia Spring 33 kW     1/2021
# 5276   5276         Volkswagen T-Roc 1.5 TSI 110 kW     1/2022
# 5282   5282                Audi Q3 35 TFSI S 110 kW     1/2021
# 5337   5337                Audi Q2 35 TFSI S 110 kW     1/2022
# 5507   5507                  Volkswagen Caddy 90 kW     1/2022
# 5619   5619                           BMW X1 100 kW     2/2022
# 5885   5885                      Dacia Spring 33 kW     1/2021
# 5942   5942             Volkswagen T-Roc TSI 110 kW     1/2022
# 6097   6097                          Kia EV6 239 kW     1/2022
# 6537   6537                 BMW X1 Automatic 140 kW     2/2022
# 6543   6543  Audi Q5 40 TDI Quattro S tronic 150 kW     1/2021
# 6666   6666                Audi Q2 35 TFSI S 110 kW     1/2022
# 6977   6977                      Dacia Spring 33 kW     1/2021
# 7220   7220            Mercedes-Benz GLA 200 120 kW     1/2022
# 7462   7462           Volkswagen ID.4 77 kWh 150 kW     1/2022
# 7914   7914                 BMW X1 Automatic 140 kW     2/2022
# 8078   8078                           BMW X3 135 kW     2/2022
# 8448   8448                Audi Q3 35 TFSI S 110 kW     1/2022
# 8492   8492                           BMW X4 135 kW     2/2022
# 9141   9141                Audi Q2 35 TFSI S 110 kW     1/2022
# 9452   9452     Seat Tarraco 1.5 TSI ACT OPF 110 kW     1/2021
# 9652   9652                           BMW X3 135 kW     2/2022
# 9793   9793                      MINI Cooper 100 kW     2/2022
#
#      First_registration   Power Transmission Fuel_type      Vendor  Ratings  \
# 535              1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 570              1/2022  118 kW       Manual    Petrol  Dealership      NaN
# 591              1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 626              1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 633              1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 777              1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 816              1/2022  150 kW    Automatic    Petrol  Dealership      NaN
# 860              1/2022  118 kW       Manual    Petrol  Dealership      NaN
# 1171             1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 1177             2/2022  110 kW    Automatic    Diesel  Dealership      4.5
# 1233             1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 1332             1/2022   85 kW       Manual    Petrol  Dealership      NaN
# 2112             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 2327             1/2022   48 kW       Manual    Petrol  Dealership      NaN
# 2698             1/2021  103 kW       Manual    Hybrid  Dealership      NaN
# 3031             2/2022  110 kW    Automatic    Diesel  Dealership      4.5
# 3521             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 3735             1/2022  150 kW    Automatic    Diesel  Dealership      NaN
# 3778             1/2022   81 kW       Manual    Petrol  Dealership      NaN
# 3797             6/2021   72 kW    Automatic    Hybrid  Dealership      5.0
# 3806             2/2022  110 kW    Automatic    Diesel  Dealership      4.5
# 3810             1/2021  110 kW    Automatic    Petrol  Dealership      NaN
# 4671             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 5276             1/2022  110 kW       Manual    Petrol  Dealership      NaN
# 5282             1/2021  110 kW    Automatic    Petrol  Dealership      NaN
# 5337             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 5507             1/2022   90 kW       Manual    Diesel  Dealership      NaN
# 5619             2/2022  100 kW    Automatic    Petrol  Dealership      4.5
# 5885             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 5942             1/2022  110 kW       Manual    Petrol  Dealership      NaN
# 6097             1/2022  239 kW    Automatic  Electric  Dealership      NaN
# 6537             2/2022  140 kW    Automatic    Diesel  Dealership      4.5
# 6543             1/2021  150 kW    Automatic    Diesel  Dealership      NaN
# 6666             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 6977             1/2021   33 kW    Automatic  Electric  Dealership      NaN
# 7220             1/2022  120 kW    Automatic    Petrol  Dealership      NaN
# 7462             1/2022  150 kW    Automatic  Electric  Dealership      NaN
# 7914             2/2022  140 kW    Automatic    Diesel  Dealership      4.5
# 8078             2/2022  135 kW    Automatic    Hybrid  Dealership      4.5
# 8448             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 8492             2/2022  135 kW    Automatic    Hybrid  Dealership      4.5
# 9141             1/2022  110 kW    Automatic    Petrol  Dealership      NaN
# 9452             1/2021  110 kW       Manual    Petrol  Dealership      NaN
# 9652             2/2022  135 kW    Automatic    Hybrid  Dealership      4.5
# 9793             2/2022  100 kW    Automatic    Petrol  Dealership      4.5
#
#          Location Price in Euro Price without Vat With or without Tax  \
# 535        Poland      23 249 €          19 214 €     without 21% VAT
# 570        Poland      21 399 €          17 685 €     without 21% VAT
# 591        Poland      31 099 €          25 702 €     without 21% VAT
# 626        Poland      49 349 €          40 784 €     without 21% VAT
# 633        Poland      53 649 €          44 338 €     without 21% VAT
# 777        Poland      31 749 €          26 239 €     without 21% VAT
# 816        Poland      47 049 €          38 883 €     without 21% VAT
# 860        Poland      22 099 €          18 264 €     without 21% VAT
# 1171       Poland      55 699 €          46 032 €     without 21% VAT
# 1177        Italy      38 099 €    Not deductible                 NaN
# 1233       Poland      55 899 €          46 198 €     without 21% VAT
# 1332       Poland      14 599 €          12 065 €     without 21% VAT
# 2112       Poland      38 449 €          31 776 €     without 21% VAT
# 2327       Poland      13 749 €          11 363 €     without 21% VAT
# 2698       Poland      21 399 €          17 685 €     without 21% VAT
# 3031        Italy      34 799 €    Not deductible                 NaN
# 3521  Netherlands      19 499 €          16 115 €     without 21% VAT
# 3735       Poland      49 349 €          40 784 €     without 21% VAT
# 3778       Poland      19 649 €          16 239 €     without 21% VAT
# 3797      Austria      21 549 €    Not deductible                 NaN
# 3806        Italy      35 499 €    Not deductible                 NaN
# 3810       Poland      39 849 €          32 933 €     without 21% VAT
# 4671  Netherlands      19 899 €          16 445 €     without 21% VAT
# 5276       Poland      24 649 €          20 371 €     without 21% VAT
# 5282       Poland      41 549 €          34 338 €     without 21% VAT
# 5337       Poland      32 199 €          26 611 €     without 21% VAT
# 5507  Netherlands      30 649 €          25 330 €     without 21% VAT
# 5619        Italy      31 349 €    Not deductible                 NaN
# 5885  Netherlands      20 299 €          16 776 €     without 21% VAT
# 5942       Poland      21 549 €          17 809 €     without 21% VAT
# 6097  Netherlands      56 099 €          46 363 €     without 21% VAT
# 6537        Italy      36 399 €    Not deductible                 NaN
# 6543       Poland      52 999 €          43 801 €     without 21% VAT
# 6666       Poland      33 299 €          27 520 €     without 21% VAT
# 6977  Netherlands      20 549 €          16 983 €     without 21% VAT
# 7220       Poland      42 299 €          34 958 €     without 21% VAT
# 7462  Netherlands      52 599 €          43 470 €     without 21% VAT
# 7914        Italy      40 699 €    Not deductible                 NaN
# 8078        Italy      60 849 €    Not deductible                 NaN
# 8448       Poland      44 649 €          36 900 €     without 21% VAT
# 8492        Italy      55 499 €    Not deductible                 NaN
# 9141       Poland      34 799 €          28 760 €     without 21% VAT
# 9452       Poland      30 849 €          25 495 €     without 21% VAT
# 9652        Italy      52 099 €    Not deductible                 NaN
# 9793        Italy      25 649 €    Not deductible                 NaN
#
#      Drive_type                           Features_1               Features_2  \
# 535         NaN  Parking assist system self-steering          Digital cockpit
# 570         NaN                   Heated front seats             Android auto
# 591         NaN                      Digital cockpit            Automatic A/C
# 626         4x4              Adaptive cruise control     Bang & Olufsen audio
# 633         4x4                        Automatic A/C                    Alarm
# 777         NaN                      Digital cockpit            Automatic A/C
# 816         4x4                       LED headlights          Digital cockpit
# 860         NaN                   Heated front seats             Android auto
# 1171        4x4                       LED headlights  Adaptive cruise control
# 1177        NaN                                  NaN                      NaN
# 1233        4x4                       LED headlights  Adaptive cruise control
# 1332        NaN                    Adaptive lighting              Rain sensor
# 2112        NaN                                  NaN                      NaN
# 2327        NaN                                  NaN                      NaN
# 2698        NaN                       LED headlights  Adaptive cruise control
# 3031        4x4                                  NaN                      NaN
# 3521        NaN                            Bluetooth             Light sensor
# 3735        4x4                       LED headlights  Adaptive cruise control
# 3778        NaN                         Android auto                      NaN
# 3797        NaN                       LED headlights            Keyless entry
# 3806        4x4                                  NaN                      NaN
# 3810        NaN                                Alarm                      NaN
# 4671        NaN                        Apple CarPlay             Android auto
# 5276        NaN                      Digital cockpit            Automatic A/C
# 5282        NaN                                Alarm                      NaN
# 5337        NaN                      Digital cockpit       Heated front seats
# 5507        NaN                       LED headlights          Digital cockpit
# 5619        NaN                                  NaN                      NaN
# 5885        NaN                            Bluetooth             Light sensor
# 5942        NaN  Parking assist system self-steering           LED headlights
# 6097        NaN                                  NaN                      NaN
# 6537        NaN                                  NaN                      NaN
# 6543        4x4                    Navigation system        On-board computer
# 6666        NaN                      Digital cockpit            Automatic A/C
# 6977        NaN                        Apple CarPlay             Android auto
# 7220        NaN  Parking assist system self-steering           LED headlights
# 7462        NaN                       LED headlights  Adaptive cruise control
# 7914        NaN                                  NaN                      NaN
# 8078        4x4                                  NaN                      NaN
# 8448        NaN                                  NaN                      NaN
# 8492        4x4                                  NaN                      NaN
# 9141        NaN                      Digital cockpit            Automatic A/C
# 9452        NaN  Parking assist system self-steering           LED headlights
# 9652        4x4                                  NaN                      NaN
# 9793        NaN                                  NaN                      NaN
#
#                    Features_3
# 535                       NaN
# 570                 Bluetooth
# 591                       NaN
# 626                 Bluetooth
# 633                       USB
# 777                       NaN
# 816         Navigation system
# 860                 Bluetooth
# 1171     Bang & Olufsen audio
# 1177                      NaN
# 1233     Bang & Olufsen audio
# 1332                      NaN
# 2112                      NaN
# 2327                      NaN
# 2698                      NaN
# 3031                      NaN
# 3521        Hill-start assist
# 3735     Bang & Olufsen audio
# 3778                      NaN
# 3797  Adaptive cruise control
# 3806                      NaN
# 3810                      NaN
# 4671        Navigation system
# 5276                    Alarm
# 5282                      NaN
# 5337            Automatic A/C
# 5507            Keyless entry
# 5619                      NaN
# 5885        Hill-start assist
# 5942                      NaN
# 6097                      NaN
# 6537                      NaN
# 6543                    Alarm
# 6666                    Alarm
# 6977        Navigation system
# 7220                      NaN
# 7462       Heated front seats
# 7914                      NaN
# 8078                      NaN
# 8448                      NaN
# 8492                      NaN
# 9141                    Alarm
# 9452                      NaN
# 9652                      NaN
# 9793                      NaN

# %% [markdown]
# ### Imputing Kms_driven with mean

# %%
selrows = data[data['Kms_driven'].str.contains(r'[@#&$%+-/*]')]
mean_km = data.drop(selrows.index)['Kms_driven'].astype(float).mean()
mean_km = str(round(mean_km,0))
mean_km
# Out:
# '29275.0'

# %%
data.query("Kms_driven == '29275.0'")
# Out:
# Empty DataFrame
# Columns: [Index, Car_Name, Kms_driven, First_registration, Power, Transmission, Fuel_type, Vendor, Ratings, Location, Price in Euro, Price without Vat, With or without Tax, Drive_type, Features_1, Features_2, Features_3]
# Index: []

# %%
count = 0
for i in selrows.index:
    data.loc[i,'Kms_driven'] = '29275.0'
    count = count+1

print(count)
# Out:
# 45

# %%
data['Kms_driven'] = data['Kms_driven'].astype(float)

# %% [markdown]
# ### First_registration

# %%
data[data['First_registration'].str.contains(r'[@#&$%+-/*]')].shape
# Out:
# (10020, 17)

# %%
data['First_registration'] = pd.to_datetime(data['First_registration'],format='%m/%Y')

# %% [markdown]
# ### cleaning Power feature

# %%
data['Power'] = data['Power'].apply(lambda x:x.strip())
data['Power'] = data['Power'].apply(lambda x: x[:-3] if x[-2:]=='kW' else x)
data['Power'] = data['Power'].apply(lambda x:x.strip())

# %% [markdown]
# ### Getting missing value from car name

# %%
for i in data[data['Power'].str.isalpha()].values:
            data.loc[i[0],'Power'] = i[1].split()[-2]

# %%
data[data['Power'].str.isalpha()]
# Out:
# Empty DataFrame
# Columns: [Index, Car_Name, Kms_driven, First_registration, Power, Transmission, Fuel_type, Vendor, Ratings, Location, Price in Euro, Price without Vat, With or without Tax, Drive_type, Features_1, Features_2, Features_3]
# Index: []

# %%
data['Power'].unique()
# Out:
# array(['140', '147', '145', '80', '110', '240', '55', '115', '113', '143',
#        '202', '85', '81', '100', '169', '177', '150', '75', '190', '49',
#        '118', '210', '74', '155', '250', '117', '76', '86', '66', '92',
#        '412', '50', '88', '152', '33', '180', '129', '221', '215', '93',
#        '53', '195', '335', '128', '135', '146', '149', '73', '165', '125',
#        '103', '184', '241', '127', '61', '96', '97', '90', '111', '163',
#        '213', '84', '170', '196', '82', '121', '239', '114', '141', '132',
#        '154', '200', '64', '133', '70', '142', '179', '87', '68', '182',
#        '214', '107', '112', '48', '178', '191', '131', '120', '280', '78',
#        '157', '259', '185', '235', '72', '320', '176', '134', '44', '186',
#        '116', '294', '279', '410', '301', '62', '260', '430', '60', '77',
#        '295', '309', '331', '208', '228', '245', '130', '54', '386', '51',
#        '160', '270', '89', '105', '225', '71', '450', '162', '287', '217',
#        '69', '230', '300', '275', '206', '193', '201', '375', '257',
#        '104', '156', '148', '285', '119', '67', '183', '390', '219',
#        '265', '243', '224', '168', '41', '350', '223', '137', '188',
#        '138', '246', '173', '174', '404', '47', '136', '316', '220',
#        '451', '95', '153', '400', '340', '63', '244', '269', '207', '198',
#        '52', '281', '175', '194', '310', '470', '199', '91', '273', '324',
#        '98', '258', '124', '336', '251', '94', '171', '271', '99', '441',
#        '187', '366', '126', '122', '227', '302', '205', '283', '345',
#        '475', '405', '108', '296', '463', '204', '109', '284', '288',
#        '460', '423', '420', '261', '330', '332', '255', '151', '358',
#        '123', '377', '59', '478', '45', '218', '307', '317', '216', '272',
#        '234', '139'], dtype=object)

# %%
data['Power'] = data['Power'].astype(int)

# %% [markdown]
# ### Transmission

# %%
data['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %% [markdown]
# ### Fuel_type

# %%
data['Fuel_type'].unique()
# Out:
# array(['Diesel', 'Hybrid', 'Petrol', 'Electric', 'LPG', 'Other fuel type',
#        'CNG', 'Hydrogen'], dtype=object)

# %% [markdown]
# ### Vendor

# %%
data['Vendor'].unique()
# Out:
# array(['Dealership', 'Used cars seller'], dtype=object)

# %% [markdown]
# ### Deleting Ratings and index

# %%
del data['Ratings']

# %%
del data['Index']
data.reset_index(drop=True,inplace=True)
data
# Out:
#                                           Car_Name  Kms_driven  \
# 0                                 BMW 520 d 140 kW     32125.0
# 1                  Kia Sorento 2.2 CRDi AWD 147 kW     63400.0
# 2                          Opel Grandland X 147 kW      2700.0
# 3                                 BMW 320 d 140 kW     26145.0
# 4                      BMW 320 d Sport Line 140 kW     28199.0
# ...                                            ...         ...
# 10015                BMW 340 Gran Turismo i 240 kW     47800.0
# 10016                Volvo V60 Momentum Pro 120 kW     16500.0
# 10017              Audi S3 2.0 TFSI Quattro 228 kW     33002.0
# 10018  Mercedes-Benz GLC 350 d 4Matic Coupe 190 kW     63000.0
# 10019             Audi A4 40 TDI S advanced 140 kW     25690.0
#
#       First_registration  Power Transmission Fuel_type            Vendor  \
# 0             2019-01-01    140    Automatic    Diesel        Dealership
# 1             2018-07-01    147    Automatic    Diesel        Dealership
# 2             2020-06-01    147    Automatic    Hybrid        Dealership
# 3             2021-03-01    140    Automatic    Diesel        Dealership
# 4             2021-02-01    140    Automatic    Diesel        Dealership
# ...                  ...    ...          ...       ...               ...
# 10015         2018-11-01    240    Automatic    Petrol        Dealership
# 10016         2021-04-01    120    Automatic    Petrol        Dealership
# 10017         2018-07-01    228    Automatic    Petrol        Dealership
# 10018         2018-11-01    190    Automatic    Diesel  Used cars seller
# 10019         2021-02-01    140    Automatic    Diesel        Dealership
#
#       Location Price in Euro Price without Vat With or without Tax Drive_type  \
# 0      Germany      32 899 €          27 189 €     without 21% VAT        NaN
# 1      Germany      34 649 €          28 636 €     without 21% VAT        4x4
# 2        Italy      35 349 €          29 214 €     without 21% VAT        4x4
# 3      Germany      39 349 €          32 520 €     without 21% VAT        NaN
# 4      Germany      40 099 €          33 140 €     without 21% VAT        NaN
# ...        ...           ...               ...                 ...        ...
# 10015  Germany      37 249 €          30 784 €     without 21% VAT        NaN
# 10016  Germany      37 249 €          30 784 €     without 21% VAT        NaN
# 10017  Germany      40 099 €          33 140 €     without 21% VAT        4x4
# 10018  Germany      42 549 €          35 164 €     without 21% VAT        4x4
# 10019  Germany      44 049 €          36 404 €     without 21% VAT        NaN
#
#                                 Features_1  \
# 0      Parking assist system self-steering
# 1                   Ventilated front seats
# 2                           LED headlights
# 3      Parking assist system self-steering
# 4      Parking assist system self-steering
# ...                                    ...
# 10015                       LED headlights
# 10016                    Heated rear seats
# 10017                       LED headlights
# 10018                       LED headlights
# 10019                       LED headlights
#
#                                 Features_2                       Features_3
# 0                           LED headlights                              NaN
# 1      Parking assist system self-steering                              NaN
# 2          Electric adjustable front seats                              NaN
# 3                           LED headlights                              NaN
# 4                           LED headlights                              NaN
# ...                                    ...                              ...
# 10015                        Keyless entry  Electric adjustable front seats
# 10016                       LED headlights                  Digital cockpit
# 10017                        Keyless entry               Heated front seats
# 10018                        Keyless entry  Electric adjustable front seats
# 10019      Electric adjustable front seats                              NaN
#
# [10020 rows x 15 columns]

# %% [markdown]
# ### Cleaning Price_Euro

# %%
data.rename(columns={"Price in Euro": "Price_Euro"},inplace=True)
data = data[data['Price_Euro'].notna()]
data.reset_index(drop=True,inplace=True)

# %%
data['Temp_price'] = data['Price_Euro']

# %%
for i in range(0,data.shape[0]):
    try:
        if data.loc[i,'Temp_price'][-1:]=='€':
            data.loc[i,'Temp_price'] = data.loc[i,'Temp_price'][:-1]
            data.loc[i,'Temp_price'] = data.loc[i,'Temp_price'].strip()
            data.loc[i,'Temp_price'] = data.loc[i,'Temp_price'].replace('\xa0','')
            
    except:
        print("Something went wrong")
        print(i)

# %%
data['Price_Euro'] = data['Temp_price']
data['Price_Euro'] = data['Price_Euro'].astype(float)
del data['Temp_price']

# %% [markdown]
# ### Deleting 'Price without Vat' 'With or without Tax'

# %%
del data['Price without Vat']
del data['With or without Tax']

# %% [markdown]
# ### Drive_type

# %%
data['Drive_type'].unique(),data['Drive_type'].isna().sum()
# Out:
# (array([nan, '4x4'], dtype=object), 7134)

# %%
data['Drive_type'].fillna('2x4',inplace=True)

# %%
data.isna().sum(),data.shape,data.dtypes
# Out:
# (Car_Name                 0
#  Kms_driven               0
#  First_registration       0
#  Power                    0
#  Transmission             0
#  Fuel_type                0
#  Vendor                   0
#  Location                 0
#  Price_Euro               0
#  Drive_type               0
#  Features_1             810
#  Features_2             951
#  Features_3            4563
#  dtype: int64,
#  (10019, 13),
#  Car_Name                      object
#  Kms_driven                   float64
#  First_registration    datetime64[ns]
#  Power                          int64
#  Transmission                  object
#  Fuel_type                     object
#  Vendor                        object
#  Location                      object
#  Price_Euro                   float64
#  Drive_type                    object
#  Features_1                    object
#  Features_2                    object
#  Features_3                    object
#  dtype: object)

# %% [markdown]
# ### Handling Car Features

# %%
f1=pd.get_dummies(data['Features_1']) # creating dummy variables for feature1
f2=pd.get_dummies(data['Features_2']) # creating dummy variables for feature2
f3=pd.get_dummies(data['Features_3']) # creating dummy variables for feature3

features_dummy= pd.concat([f1,f2,f3], axis=1)

features_dummy.info()

features_same_name=features_dummy.groupby(level=0,axis=1).sum()

features_same_name
features_score=features_same_name.sum(axis=1)
features_score

data = pd.concat([data,features_score], axis=1)
data = data.rename(columns={0: 'features_score'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Columns: 224 entries, Adaptive cruise control to Xenon headlights
# dtypes: uint8(224)
# memory usage: 2.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Car_Name            10019 non-null  object
#  1   Kms_driven          10019 non-null  float64
#  2   First_registration  10019 non-null  datetime64[ns]
#  3   Power               10019 non-null  int64
#  4   Transmission        10019 non-null  object
#  5   Fuel_type           10019 non-null  object
#  6   Vendor              10019 non-null  object
#  7   Location            10019 non-null  object
#  8   Price_Euro          10019 non-null  float64
#  9   Drive_type          10019 non-null  object
#  10  Features_1          9209 non-null   object
#  11  Features_2          9068 non-null   object
#  12  Features_3          5456 non-null   object
#  13  features_score      10019 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Droping car features

# %%
data.drop(labels=['Features_1','Features_2','Features_3'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Car_Name            10019 non-null  object
#  1   Kms_driven          10019 non-null  float64
#  2   First_registration  10019 non-null  datetime64[ns]
#  3   Power               10019 non-null  int64
#  4   Transmission        10019 non-null  object
#  5   Fuel_type           10019 non-null  object
#  6   Vendor              10019 non-null  object
#  7   Location            10019 non-null  object
#  8   Price_Euro          10019 non-null  float64
#  9   Drive_type          10019 non-null  object
#  10  features_score      10019 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 861.1+ KB

# %% [markdown]
# ### Handling Duplicated

# %%
duplicates = data[data.duplicated()]
duplicates.shape
# Out:
# (89, 11)

# %%
duplicates.sort_values(by='Car_Name').head(10)
# Out:
#                                     Car_Name  Kms_driven First_registration  \
# 4980          Abarth 595 Competizione 132 kW      6668.0         2021-03-01
# 1099          Abarth 595 Competizione 132 kW     12922.0         2020-12-01
# 8274                Alfa Romeo Giulia 140 kW     13200.0         2021-01-01
# 5664            Alfa Romeo Giulia 2.2 155 kW     19478.0         2020-08-01
# 3237            Alfa Romeo Giulia 2.2 155 kW     19478.0         2020-08-01
# 3704        Alfa Romeo Giulia 2.2 AT8 140 kW     26000.0         2021-08-01
# 8406        Alfa Romeo Giulia 2.2 AT8 140 kW     26000.0         2021-08-01
# 9087        Alfa Romeo Giulia 2.2 AT8 140 kW     22599.0         2020-01-01
# 8650  Alfa Romeo Giulietta 1.6 16V TCT 88 kW     46100.0         2019-05-01
# 9933               Alfa Romeo Stelvio 154 kW     51093.0         2020-07-01
#
#       Power Transmission Fuel_type      Vendor Location  Price_Euro  \
# 4980    132       Manual    Petrol  Dealership  Germany     29849.0
# 1099    132       Manual    Petrol  Dealership  Germany     27649.0
# 8274    140    Automatic    Diesel  Dealership    Italy     43949.0
# 5664    155    Automatic    Diesel  Dealership    Italy     41699.0
# 3237    155    Automatic    Diesel  Dealership    Italy     41699.0
# 3704    140    Automatic    Diesel  Dealership    Italy     39649.0
# 8406    140    Automatic    Diesel  Dealership    Italy     39649.0
# 9087    140    Automatic    Diesel  Dealership    Italy     35999.0
# 8650     88    Automatic    Diesel  Dealership    Italy     18449.0
# 9933    154    Automatic    Diesel  Dealership    Italy     51699.0
#
#      Drive_type  features_score
# 4980        2x4               3
# 1099        2x4               3
# 8274        2x4               1
# 5664        4x4               3
# 3237        4x4               3
# 3704        2x4               3
# 8406        2x4               3
# 9087        2x4               3
# 8650        2x4               1
# 9933        2x4               3

# %%
temp_data = data
temp_data.shape
# Out:
# (10019, 11)

# %%
temp_data.drop_duplicates(keep='first',inplace=True)
temp_data.shape
# Out:
# (9930, 11)

# %%
import sweetviz as sv
sweet_report = sv.analyze(temp_data,target_feat='Price_Euro')
sweet_report.show_html('carsvago_EDA.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report carsvago_EDA.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
temp_data.dtypes
# Out:
# Car_Name                      object
# Kms_driven                   float64
# First_registration    datetime64[ns]
# Power                          int64
# Transmission                  object
# Fuel_type                     object
# Vendor                        object
# Location                      object
# Price_Euro                   float64
# Drive_type                    object
# features_score                 int64
# dtype: object

# %% [markdown]
# #### Export to csv

# %%
temp_data.to_csv('Carsvago_cleaned_data.csv')

# %%
# value = '' 
# name = ''


# def update_value(val,f_name,idx):
#     print(data.loc[idx,f_name])
#     if str(data.loc[idx,f_name]) != 'nan':
#         global value
#         value = data.loc[idx,f_name]
#     else:
#         value = ''
#     data.loc[idx,f_name] = val
#     return



# #for i in data[data['Kms_driven'].str.endswith(' km')==False].head(1).values:
# #['Kms_driven','First_registration','Power','Transmission','Fuel_type','Drive_type']

# for i in data.values:
#     skip = 0
#     for c in range(0,len(columns)):
#         if c == 0 or skip==1:
#             value = str(data.loc[i[0],columns[c]])
#             skip = 0
#         if len(value)==0:
#             continue
#         name = get_feature_name(value)
#         if name == columns[c]:
#             skip = 1
#             continue
#         v = value
#         n = name
#         print(v,n,i[0])
#         update_value(v,n,i[0])
